# %% [markdown]
# # <center>Image captioning model inference

# %%
from src.image_captioner import ImageCaptioner
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 20 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
# import joblib
# from src.data_processing.vocabulary import Vocabulary
# vocab = Vocabulary()
# joblib.dump(vocab, 'vocab/vocab.joblib')

# %% [markdown]
# **Checkpoint** can be downloaded from *Google Drive* here: [<b>link</b>](https://drive.google.com/file/d/1xEGNuHPAuG85xdnM5eVtTBnPSdHAJyJo/view?usp=drive_link)
# **Vocabulary** can be downloaded from *GitHub* here: [<b>link</b>](https://github.com/ScReameer/Image-captioning/tree/main/vocab)

# %%
# VOCAB_PATH = 'vocab/vocab.joblib' # Default path to vocab file
CHECKPOINT_PATH = 'weights/checkpoint.ckpt' # Set your checkpoint path
image_captioner = ImageCaptioner(checkpoint_path=CHECKPOINT_PATH)

# %% [markdown]
# ## Examples
# Image from path

# %%
image_captioner.caption_image('/mnt/s/CV/text_recognition_examples/classic.jpg')
# Out:
# Predicted caption: classic

# %%
image_captioner.caption_image('/mnt/s/CV/text_recognition_examples/cola.jpg')
# Out:
# Predicted caption: cacd

# %%
image_captioner.caption_image('/mnt/s/CV/text_recognition_examples/ya.jpg')
# Out:
# Predicted caption: yandex

# %%
image_captioner.caption_image('/mnt/s/CV/text_recognition_examples/spot.jpg')
# Out:
# Predicted caption: spotinye

# %%
image_captioner.caption_image('/mnt/s/CV/text_recognition_examples/disc.jpg')
# Out:
# Predicted caption: piscord

# %%
image_captioner.caption_image('/mnt/s/CV/text_recognition_examples/yt.jpg')
# Out:
# Predicted caption: sutttnel
