# %% [markdown]
# # <center>ViTSTR-Transducer inference

# %%
import os
os.environ['NUMEXPR_MAX_THREADS'] = '20'
from src.image_captioner import ImageCaptioner

# %% [markdown]
# **Checkpoint** can be downloaded from *Google Drive* here: [<b>link</b>](https://drive.google.com/file/d/17PJkvuHbpqF01t7xAyBsOmQLigVcdQDs/view?usp=drive_link)

# %%
EXAMPLES_PATH = '/mnt/s/CV/text_recognition_examples'
CHECKPOINT_PATH = 'weights/checkpoint-v2.ckpt' # Set your checkpoint path
image_captioner = ImageCaptioner(checkpoint_path=CHECKPOINT_PATH)

# %% [markdown]
# ## Examples

# %%
for filename in os.listdir(EXAMPLES_PATH):
    predicted_caption = image_captioner.caption_image(os.path.join(EXAMPLES_PATH, filename), show_img=True)
# Out:
# Predicted caption: blossom
# Predicted caption: classic
# Predicted caption: deadpool
# Predicted caption: discord
# Predicted caption: hellboy
# Predicted caption: love
# Predicted caption: pepsi
# Predicted caption: spotify
# Predicted caption: yandex
# Predicted caption: youlube
